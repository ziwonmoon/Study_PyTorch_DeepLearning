# %% [markdown]
# ## Data Load

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

from torch.utils.data import TensorDataset
from torch.utils.data import DataLoader

# %%
x_train = torch.FloatTensor([[73, 80, 75],
                             [93, 88, 93],
                             [89, 91, 90],
                             [96, 98, 100],
                             [73, 66, 70]])
y_train = torch.FloatTensor([[152], [185], [180], [196], [142]])

# %%
dataset = TensorDataset(x_train, y_train)
dataloader = DataLoader(dataset, batch_size=2, shuffle=True)

model = nn.Linear(3, 1)
optimizer = torch.optim.SGD(model.parameters(), lr=1e-5)

# %%
nb_epochs = 20
for epoch in range(nb_epochs + 1):
  for batch_idx, samples in enumerate(dataloader):
    #print(batch_idx)
    #print(samples)
    x_train, y_train = samples
    prediction = model(x_train)

    cost = F.mse_loss(prediction, y_train)

    optimizer.zero_grad()
    cost.backward()
    optimizer.step()

    print('Epoch {:4d}/{} Batch {}/{} Cost: {:.6f}'.format(
        epoch, nb_epochs, batch_idx+1, len(dataloader),
        cost.item()
    ))
# Out:
# Epoch    0/20 Batch 1/3 Cost: 4.675218
# Epoch    0/20 Batch 2/3 Cost: 1.503379
# Epoch    0/20 Batch 3/3 Cost: 8.515076
# Epoch    1/20 Batch 1/3 Cost: 4.948212
# Epoch    1/20 Batch 2/3 Cost: 2.210792
# Epoch    1/20 Batch 3/3 Cost: 3.429244
# Epoch    2/20 Batch 1/3 Cost: 4.094707
# Epoch    2/20 Batch 2/3 Cost: 4.173097
# Epoch    2/20 Batch 3/3 Cost: 0.791149
# Epoch    3/20 Batch 1/3 Cost: 1.709613
# Epoch    3/20 Batch 2/3 Cost: 4.990648
# Epoch    3/20 Batch 3/3 Cost: 5.831382
# Epoch    4/20 Batch 1/3 Cost: 3.072336
# Epoch    4/20 Batch 2/3 Cost: 5.419641
# Epoch    4/20 Batch 3/3 Cost: 5.744966
# Epoch    5/20 Batch 1/3 Cost: 4.355178
# Epoch    5/20 Batch 2/3 Cost: 2.969462
# Epoch    5/20 Batch 3/3 Cost: 3.667725
# Epoch    6/20 Batch 1/3 Cost: 4.033342
# Epoch    6/20 Batch 2/3 Cost: 4.131985
# Epoch    6/20 Batch 3/3 Cost: 0.811638
# Epoch    7/20 Batch 1/3 Cost: 4.962763
# Epoch    7/20 Batch 2/3 Cost: 0.773077
# Epoch    7/20 Batch 3/3 Cost: 7.548156
# Epoch    8/20 Batch 1/3 Cost: 2.644608
# Epoch    8/20 Batch 2/3 Cost: 6.442913
# Epoch    8/20 Batch 3/3 Cost: 4.158398
# Epoch    9/20 Batch 1/3 Cost: 3.986213
# Epoch    9/20 Batch 2/3 Cost: 4.755675
# Epoch    9/20 Batch 3/3 Cost: 1.826432
# Epoch   10/20 Batch 1/3 Cost: 4.710838
# Epoch   10/20 Batch 2/3 Cost: 3.485287
# Epoch   10/20 Batch 3/3 Cost: 2.006440
# Epoch   11/20 Batch 1/3 Cost: 4.079371
# Epoch   11/20 Batch 2/3 Cost: 3.147575
# Epoch   11/20 Batch 3/3 Cost: 4.221866
# Epoch   12/20 Batch 1/3 Cost: 0.901417
# Epoch   12/20 Batch 2/3 Cost: 4.839247
# Epoch   12/20 Batch 3/3 Cost: 6.903368
# Epoch   13/20 Batch 1/3 Cost: 4.113558
# Epoch   13/20 Batch 2/3 Cost: 3.657455
# Epoch   13/20 Batch 3/3 Cost: 1.684696
# Epoch   14/20 Batch 1/3 Cost: 4.801429
# Epoch   14/20 Batch 2/3 Cost: 0.964587
# Epoch   14/20 Batch 3/3 Cost: 7.203477
# Epoch   15/20 Batch 1/3 Cost: 4.546968
# Epoch   15/20 Batch 2/3 Cost: 3.258876
# Epoch   15/20 Batch 3/3 Cost: 5.373800
# Epoch   16/20 Batch 1/3 Cost: 5.456121
# Epoch   16/20 Batch 2/3 Cost: 3.760091
# Epoch   16/20 Batch 3/3 Cost: 4.044312
# Epoch   17/20 Batch 1/3 Cost: 6.797035
# Epoch   17/20 Batch 2/3 Cost: 5.375330
# Epoch   17/20 Batch 3/3 Cost: 3.236936
# Epoch   18/20 Batch 1/3 Cost: 3.208116
# Epoch   18/20 Batch 2/3 Cost: 3.340737
# Epoch   18/20 Batch 3/3 Cost: 7.191360
# Epoch   19/20 Batch 1/3 Cost: 2.537381
# Epoch   19/20 Batch 2/3 Cost: 6.416888
# Epoch   19/20 Batch 3/3 Cost: 4.073516
# Epoch   20/20 Batch 1/3 Cost: 0.185192
# Epoch   20/20 Batch 2/3 Cost: 5.334235
# Epoch   20/20 Batch 3/3 Cost: 6.864214

# %%
new_var = torch.FloatTensor([[73, 80, 75]])
pred_y = model(new_var)
print("훈련 후 입력이 73, 80, 75일 때의 예측값 :", pred_y)
# Out:
# 훈련 후 입력이 73, 80, 75일 때의 예측값 : tensor([[154.5509]], grad_fn=<AddmmBackward0>)

# %% [markdown]
# ## Custom Dataset

# %% [markdown]
# ```Python
# class CustomDataset(torch.utils.data.Dataset):
#   def __init__(self):
#     #데이터셋의 전처리
#   def __len__(self):
#     #데이터셋의 길이, 즉 총 샘플의 수 len(CustomDataset)
#   def __getitem__(self, idx):
#     #데이터셋에서 특정 1개의 샘플을 가져오는 매서드 CustomDataset[idx]
# ```

# %%
import torch
import torch.nn.functional as F
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

# %%
class CustomDataset(Dataset):
  def __init__(self):
    self.x_data = [[73, 80, 75],
                  [93, 88, 93],
                  [89, 91, 90],
                  [96, 98, 100],
                  [73, 66, 70]]
    self.y_data = [[152], [185], [180], [196], [142]]

  def __len__(self):
    return len(self.x_data)

  def __getitem__(self, idx):
    x = torch.FloatTensor(self.x_data[idx])
    y = torch.FloatTensor(self.y_data[idx])
    return x, y

# %%
dataset = CustomDataset()
dataloader = DataLoader(dataset, batch_size=2, shuffle=True)

model = torch.nn.Linear(3, 1)
optimizer = torch.optim.SGD(model.parameters(), lr=1e-5)

# %%
nb_epochs = 20
for epoch in range(nb_epochs + 1):
  for batch_idx, samples in enumerate(dataloader):
    x_train, y_train = samples
    prediction = model(x_train)

    cost = F.mse_loss(prediction, y_train)

    optimizer.zero_grad()
    cost.backward()
    optimizer.step()

    print('Epoch {:4d}/{} Batch {}/{} Cost: {:.6f}'.format(
        epoch, nb_epochs, batch_idx+1, len(dataloader),
        cost.item()
    ))
# Out:
# Epoch    0/20 Batch 1/3 Cost: 33150.582031
# Epoch    0/20 Batch 2/3 Cost: 8235.524414
# Epoch    0/20 Batch 3/3 Cost: 3938.990234
# Epoch    1/20 Batch 1/3 Cost: 869.016418
# Epoch    1/20 Batch 2/3 Cost: 248.515167
# Epoch    1/20 Batch 3/3 Cost: 90.035011
# Epoch    2/20 Batch 1/3 Cost: 25.872471
# Epoch    2/20 Batch 2/3 Cost: 7.787464
# Epoch    2/20 Batch 3/3 Cost: 4.251452
# Epoch    3/20 Batch 1/3 Cost: 1.910631
# Epoch    3/20 Batch 2/3 Cost: 0.831648
# Epoch    3/20 Batch 3/3 Cost: 2.015355
# Epoch    4/20 Batch 1/3 Cost: 1.159614
# Epoch    4/20 Batch 2/3 Cost: 2.179358
# Epoch    4/20 Batch 3/3 Cost: 0.036648
# Epoch    5/20 Batch 1/3 Cost: 0.097898
# Epoch    5/20 Batch 2/3 Cost: 1.566416
# Epoch    5/20 Batch 3/3 Cost: 2.189349
# Epoch    6/20 Batch 1/3 Cost: 0.286866
# Epoch    6/20 Batch 2/3 Cost: 2.238820
# Epoch    6/20 Batch 3/3 Cost: 2.213074
# Epoch    7/20 Batch 1/3 Cost: 1.844013
# Epoch    7/20 Batch 2/3 Cost: 2.017101
# Epoch    7/20 Batch 3/3 Cost: 0.000023
# Epoch    8/20 Batch 1/3 Cost: 0.471892
# Epoch    8/20 Batch 2/3 Cost: 0.579143
# Epoch    8/20 Batch 3/3 Cost: 4.024023
# Epoch    9/20 Batch 1/3 Cost: 1.881668
# Epoch    9/20 Batch 2/3 Cost: 1.597005
# Epoch    9/20 Batch 3/3 Cost: 0.004692
# Epoch   10/20 Batch 1/3 Cost: 1.220211
# Epoch   10/20 Batch 2/3 Cost: 0.493279
# Epoch   10/20 Batch 3/3 Cost: 3.037823
# Epoch   11/20 Batch 1/3 Cost: 0.718663
# Epoch   11/20 Batch 2/3 Cost: 2.853415
# Epoch   11/20 Batch 3/3 Cost: 0.083575
# Epoch   12/20 Batch 1/3 Cost: 0.715724
# Epoch   12/20 Batch 2/3 Cost: 2.098020
# Epoch   12/20 Batch 3/3 Cost: 0.057215
# Epoch   13/20 Batch 1/3 Cost: 1.866709
# Epoch   13/20 Batch 2/3 Cost: 0.872195
# Epoch   13/20 Batch 3/3 Cost: 0.169822
# Epoch   14/20 Batch 1/3 Cost: 1.903558
# Epoch   14/20 Batch 2/3 Cost: 0.797483
# Epoch   14/20 Batch 3/3 Cost: 0.194543
# Epoch   15/20 Batch 1/3 Cost: 0.912863
# Epoch   15/20 Batch 2/3 Cost: 0.414423
# Epoch   15/20 Batch 3/3 Cost: 3.506190
# Epoch   16/20 Batch 1/3 Cost: 1.537800
# Epoch   16/20 Batch 2/3 Cost: 1.747116
# Epoch   16/20 Batch 3/3 Cost: 0.069813
# Epoch   17/20 Batch 1/3 Cost: 0.991478
# Epoch   17/20 Batch 2/3 Cost: 1.705768
# Epoch   17/20 Batch 3/3 Cost: 0.146265
# Epoch   18/20 Batch 1/3 Cost: 0.536808
# Epoch   18/20 Batch 2/3 Cost: 1.407358
# Epoch   18/20 Batch 3/3 Cost: 2.209534
# Epoch   19/20 Batch 1/3 Cost: 0.556440
# Epoch   19/20 Batch 2/3 Cost: 2.225404
# Epoch   19/20 Batch 3/3 Cost: 0.128624
# Epoch   20/20 Batch 1/3 Cost: 1.540579
# Epoch   20/20 Batch 2/3 Cost: 1.836175
# Epoch   20/20 Batch 3/3 Cost: 0.015614

# %%
new_var = torch.FloatTensor([[73, 80, 75]])
pred_y = model(new_var)
print("훈련 후 입력이 73, 80, 75 일 때 의 예측값 : ", pred_y)
# Out:
# 훈련 후 입력이 73, 80, 75 일 때 의 예측값 :  tensor([[150.7919]], grad_fn=<AddmmBackward0>)
